# %%
import json

# %% [markdown]
# #### Rules:
# 1. Cant use single quotes
# 2. No comments

# %%
json_data = '{"a":1, "b":2, "c":3, "d":4}'

# %%
x = json.loads(json_data)

# %%
x
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
x["b"]
# Out:
# 2

# %%
with open("j1.json", "w") as f:
    json.dump(x, f)  #Will put value of x in j1.json file
