# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name": ["Shail", "Raj", "Meet", "Mohit"],
    "marks": [90, 20, 43, 80],
    "city": ["Ahmedabad", "Kolkata", "Mumbai", "Ahmedabad"]
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#     name  marks       city
# 0  Shail     90  Ahmedabad
# 1    Raj     20    Kolkata
# 2   Meet     43     Mumbai
# 3  Mohit     80  Ahmedabad

# %% [markdown]
# read modifications

# %%
df.to_csv("emp.csv")

# %%
df.to_csv("emp_indexfalse.csv", index=False)

# %%
df.head(2)
# will print first 2 rows
# Out:
#     name  marks       city
# 0  Shail     90  Ahmedabad
# 1    Raj     20    Kolkata

# %%
df.tail(2)
# will print last 2 rows
# Out:
#     name  marks       city
# 2   Meet     43     Mumbai
# 3  Mohit     80  Ahmedabad

# %%
df.describe()
# will perform various numerical functions on numerical columns (currently only marks)
# Out:
#         marks
# count   4.000
# mean   58.250
# std    32.541
# min    20.000
# 25%    37.250
# 50%    61.500
# 75%    82.500
# max    90.000

# %% [markdown]
# Read from csv

# %%
train = pd.read_csv("train.csv")

# %%
train
# Out:
#   Unnamed: 0  TrainNo  speed       city
# 0      first   123456     50  Ahmedabad
# 1     second   456321     20    Kolkata
# 2      third    98632     43     Mumbai
# 3     fourth   282047     80  Ahmedabad

# %% [markdown]
# basic printing

# %%
train["speed"]
# Out:
# 0    50
# 1    20
# 2    43
# 3    80
# Name: speed, dtype: int64

# %%
train['speed'][0]
# Out:
# np.int64(50)

# %% [markdown]
# change value of an element (warning is given)

# %%
train['speed'][0] = 50
# Out:
# C:\Users\shail\AppData\Local\Temp\ipykernel_17436\2070240468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['speed'][0] = 50

# %%
train
# Out:
#   Unnamed: 0  TrainNo  speed       city
# 0      first   123456     50  Ahmedabad
# 1     second   456321     20    Kolkata
# 2      third    98632     43     Mumbai
# 3     fourth   282047     80  Ahmedabad

# %% [markdown]
# put data into csv file

# %%
train.to_csv('train.csv')

# %% [markdown]
# change value of index

# %%
train.index = ['first', 'second', 'third', 'fourth']

# %%
train
# Out:
#        Unnamed: 0  TrainNo  speed       city
# first       first   123456     50  Ahmedabad
# second     second   456321     20    Kolkata
# third       third    98632     43     Mumbai
# fourth     fourth   282047     80  Ahmedabad
